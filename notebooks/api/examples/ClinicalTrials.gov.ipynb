# %% [markdown]
# # e(BE:L) API methods

# %%
import api_doc
api_doc.get_api_methods_by_tag('ClinicalTrials.gov')
# Out:
# <h2>1. Get clinical trials by condition</h2>
# <b style="color: rgb(98,98,98); text-decoration: underline;">Description:</b> <p>Get clinical trials by condition</p>
# <b>Tags:</b> ['ClinicalTrials.gov']
# <b>Server path:</b> /api/v1/clinical_trial/by_condition
#                data type                    description  \
# parameter name
# condition         string  Condition (use % as wildcard)
# page_size        integer               Results per page
# page             integer  Page number (starting with 1)
#
#                                            example options default  required
# parameter name
# condition       Mild to Severe Alzheimer's Disease                     False
# page_size                                        1            10.0     False
# page                                             1             1.0     False
# ...
