# %% [markdown]
# # e(BE:L) algorithsm API methods

# %%
import api_doc
api_doc.get_api_methods_by_tag('e(BE:L) algorithm')
# Out:
# <h2>1. Get contradictory edges from BEL.</h2>
# <b style="color: rgb(98,98,98); text-decoration: underline;">Description:</b> <h1>Validate causal BEL edges against Expression Atlas differential expression transcriptome data</h1>
# <p><strong><em>NOTE</em></strong>: Expression Atlas data where pre-filtered for p-value &lt;= 0.05 and (log2foldchange &gt;= 1 or &lt;= -1)</p>
# <p>Validation of  <strong><em>BEL relations</em></strong> against diffenrential expression analysis (DEA)
# transcriptome data (from <a href="https://www.ebi.ac.uk/gxa/home">Expression Atlas</a>). Following  relation classes used:</p>
# <ul>
# <li>directly_increases</li>
# <li>increases</li>
# <li>decreases</li>
# <li>directly_decreases</li>
# <li>positive_correlation</li>
# <li>negative_correlation</li>
# </ul>
# <p>Expression Atlas data itself can be be queried in the same API <a href="#/Expression%20Atlas">here</a>.</p>
# <h2>Algorithsm</h2>
# <ul>
# ...
